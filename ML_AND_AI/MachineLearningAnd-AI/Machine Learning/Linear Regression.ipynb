# %% [markdown]
# ### Linear Regression Assignment

# %% [markdown]
# # Problem Statement:
#     1. You have access to the salary information of several employees along with their Years of
#     Experience. Using Linear regression analysis in machine learning, create a linear
#     regression model can predict the salary of an employee based on the years of
#     experience.
#     2. House prices can be an ever changing trend, but it does change based on certain
#     parameters. You are provided with housing data that has information on various houses
#     and their prices. Use the data at hand to predict the prices of the house using linear
#     regression in machine learning.

# %% [markdown]
# # Dataset Information:
#     1. Data.csv - This dataset contains two columns with 30 entries each for employee years
#     of experience and their salary.
# ![image.png](attachment:cc2a3b64-9ff4-45c0-bdf1-d7ae374af851.png)

# %% [markdown]
# # 2. Housing.csv - The dataset is considerably larger and contains the following columns in the data. The dataset contains more than 20,000 entries for information about the houses, prices and various other parameters.
# ![image.png](attachment:46fa457f-cf40-4a16-8c2a-6ccbb100bf2e.png)
# ![image.png](attachment:dbdf465e-fe06-4fa3-9df8-7535f76b9175.png)
# # Explore the datasets, and perform EDA on both the datasets before starting the following exercise.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("data.csv")
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# # 1. How many employees having more than 5 years experience are earning more than 60000?
#     a. 41
#     b. 12
#     c. 21
#     d. 14

# %%
filter_more_th_5yrs_emp_ern_mthan_60k = ((data["YearsExperience"] >5) & (data["Salary"] > 60000))
data[filter_more_th_5yrs_emp_ern_mthan_60k].count()
# Out:
# YearsExperience    14
# Salary             14
# dtype: int64

# %% [markdown]
# # Answer D

# %% [markdown]
# # 2. How many employees are earning between 50000-80000?
#     a. 14
#     b. 12
#     c. 10
#     d. 13

# %%
filter_emp_ern_mthan_50k_to_80k = ((data["Salary"] >= 50000) & (data["Salary"] <= 80000))
data[filter_emp_ern_mthan_50k_to_80k].count()
# Out:
# YearsExperience    12
# Salary             12
# dtype: int64

# %% [markdown]
# # Answer B

# %% [markdown]
# # 3. The scatter plot in the following image shows the relationship between the “YearsExperience” and “Salary” columns. What possible inferences can be drawn from the plot?
# ![image.png](attachment:3764b23b-4228-4d21-8f42-fb35c38328e3.png)

# %%
# sns.scatter(data["Salary"],data["YearsExperience"])
# plt.scatter(data["YearsExperience"],data["Salary"])
# plt.plot(data["YearsExperience"],data["Salary"])
scatter_kws={"color" : "blue", "edgecolor" : "grey", "alpha" : 0.4}
line_kws={"color" : "red", "linewidth" : 1}
sns.regplot (data = data, x="YearsExperience", y="Salary", scatter_kws=scatter_kws, line_kws=line_kws)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %% [markdown]
# # Answer A

# %% [markdown]
# ![image.png](attachment:ee40b478-efe2-4d9c-bbc8-47189c92fc29.png)

# %% [markdown]
# ![image.png](attachment:48c90787-e588-4a7e-af57-0be91b11cc82.png)

# %% [markdown]
# # Answer B

# %% [markdown]
# # 5. What all inferences can be drawn from the table shown below:
# ![image.png](attachment:b547d46e-6d0e-450e-a756-a517fb7ec83f.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("data.csv")
data.describe()

df = data.describe().reset_index()
df
# Out:
#    index  YearsExperience         Salary
# 0  count        30.000000      30.000000
# 1   mean         5.313333   76003.000000
# 2    std         2.837888   27414.429785
# 3    min         1.100000   37731.000000
# 4    25%         3.200000   56720.750000
# 5    50%         4.700000   65237.000000
# 6    75%         7.700000  100544.750000
# 7    max        10.500000  122391.000000

# %%
min_of_YearsExperience = df[df["index"]=="min"]["YearsExperience"]
max_of_YearsExperience = df[df["index"]=="max"]["YearsExperience"]

min_Salary =  df[df["index"]=="min"]["Salary"]
max_Salary = df[df["index"]=="max"]["Salary"]

range_of_YearsExperience = float(max_of_YearsExperience) - float(min_of_YearsExperience)
range_of_Salary = float(max_Salary) - float(min_Salary)
range_of_Salary
print("The range of the “YearsExperience” and “Salary” data is({},{})".format(range_of_YearsExperience,range_of_Salary))
# Out:
# The range of the “YearsExperience” and “Salary” data is(9.4,84660.0)

# %% [markdown]
# # Answer A

# %% [markdown]
# # 6. To split the dataset into training and testing data, if we use the following code.
#     X = data['YearsExperience']
#     y = data['Salary']
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
#     random_state=0) What does it mean when we write the test size as 0.2?
#     a. The testing data will be 2% accurate.
#     b. The testing data will have 80% samples from the total population.
#     c. The testing data will have 2% samples from the total population.
#     d. The training data will consist of 80% of the samples from the total population.

# %% [markdown]
# # Answer D

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("data.csv")
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.scatter(data["YearsExperience"],data["Salary"])

# %%
from sklearn.model_selection import train_test_split
# train_test_split
X = data[["YearsExperience"]]
y = data[["Salary"]]
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.2)
# len(x)
# y

# %%
len(X_test)
# Out:
# 6

# %%
X_test
# Out:
# 0     1.1
# 6     3.0
# 13    4.1
# 5     2.9
# 10    3.9
# 24    8.7
# Name: YearsExperience, dtype: float64

# %%
X_train
# Out:
# 3      2.0
# 16     5.1
# 26     9.5
# 14     4.5
# 27     9.6
# 12     4.0
# 20     6.8
# 29    10.5
# 19     6.0
# 17     5.3
# 2      1.5
# 15     4.9
# 25     9.0
# 21     7.1
# 4      2.2
# 22     7.9
# 23     8.2
# 8      3.2
# 1      1.3
# 9      3.7
# 28    10.3
# 7      3.2
# 11     4.0
# 18     5.9
# Name: YearsExperience, dtype: float64

# %%
y_train
# Out:
# 3      43525.0
# 16     66029.0
# 26    116969.0
# 14     61111.0
# 27    112635.0
# 12     56957.0
# 20     91738.0
# 29    121872.0
# 19     93940.0
# 17     83088.0
# 2      37731.0
# 15     67938.0
# 25    105582.0
# 21     98273.0
# 4      39891.0
# 22    101302.0
# 23    113812.0
# 8      64445.0
# 1      46205.0
# 9      57189.0
# 28    122391.0
# 7      54445.0
# 11     55794.0
# 18     81363.0
# Name: Salary, dtype: float64

# %%
y_test
# Out:
# 0      39343.0
# 6      60150.0
# 13     57081.0
# 5      56642.0
# 10     63218.0
# 24    109431.0
# Name: Salary, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     YearsExperience
# 25              9.0
# 0               1.1
# 13              4.1
# 11              4.0
# 17              5.3
# 27              9.6

# %%
clf.predict(X_test)
# Out:
# array([[112064.25077818],
#        [ 36060.87678105],
#        [ 64922.91753945],
#        [ 63960.84951417],
#        [ 76467.73384281],
#        [117836.65892986]])

# %%
clf.score(X_test, y_test)
# Out:
# 0.9816423482070253

# %%
from sklearn.model_selection import train_test_split
# train_test_split
X = data[["YearsExperience"]]
y = data[["Salary"]]
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.2, random_state =10)
# len(x)
# y
clf = LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
clf.score(X_test, y_test)
# Out:
# 0.9816423482070253

# %%
yax =clf.predict(X_test)
yax
# Out:
# array([[89715.76498848],
#        [56031.05821174],
#        [53223.99931368],
#        [40124.39112273],
#        [44802.8226195 ],
#        [92522.82388655]])

# %%
X_test
# Out:
#     YearsExperience
# 20              6.8
# 7               3.2
# 5               2.9
# 2               1.5
# 3               2.0
# 21              7.1

# %%
plt.scatter(data["YearsExperience"],data["Salary"])

# %%
# plt.scatter(X_test["YearsExperience"],yax[0])
yax[0]
# Out:
# array([89715.76498848])

# %% [markdown]
# # 7. In the above example code, we have taken the random state as 0, if we change the random state as 42, what does it mean for our training and testing data?
#     a. The shape of the training data will become (42,)
#     b. The shape of the training data will become (42,2)
#     c. The random state does not have any effect on the shape of the data.
#     d. The random state will increase the efficiency of the model by 42%.

# %%
from sklearn.model_selection import train_test_split
# train_test_split
X = data[["YearsExperience"]]
y = data[["Salary"]]
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.4,random_state =42)
# len(x)
# y
clf = LinearRegression()
clf.fit(X_train,y_train)
X_test
# Out:
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1

# %% [markdown]
# # Answer C

# %% [markdown]
# # 8. If the r2 score calculated in the above example is 0.98 , change the sample size of the training and testing set in the ratio 60:40, and build a linear regression model again. After plotting the best fit line on the test data, calculate the r2_score for the new model.
# # a. 0.98
# # b. 0.96
# # c. 1.0
# # d. 0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
# train_test_split
X = data[["YearsExperience"]]
y = data[["Salary"]]
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.4) #,random_state =10)
# len(x)
# y
clf = LinearRegression()
clf.fit(X_train,y_train)

mod_pred=clf.predict(X_test) 
print(r2_score(mod_pred, y_test))
# Out:
# 0.9639618962814063

# %% [markdown]
# # Answer A

# %%
clf.score(X_test, y_test)
# Out:
# 0.9666277567523865

# %% [markdown]
# # 9. If while fitting the model with training and testing data, you get the following error ValueError: Expected 2D array, got 1D array instead: What could be the issue with the data, and how can you solve it?
#     a. Reshape the data to a two dimensional array
#     b. Reshape the data to two arrays of 1-D each.
#     c. Both A and B
#     d. None of the above

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("data.csv")
from sklearn.model_selection import train_test_split
# train_test_split
X = data["YearsExperience"]
y = data[["Salary"]]
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.2)
clf = LinearRegression()
clf.fit(X_train,y_train)

mod_pred=clf.predict(X_test) 
print(r2_score(mod_pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 11
#       9 X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.2)
#      10 clf = LinearRegression()
# ---> 11 clf.fit(X_train,y_train)
#      13 mod_pred=clf.predict(X_test)
#      14 print(r2_score(mod_pred, y_test))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
data = pd.read_csv("data.csv")
from sklearn.model_selection import train_test_split
# train_test_split
X = data[["YearsExperience"]]
y = data[["Salary"]]
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.2)
clf = LinearRegression()
clf.fit(X_train,y_train)

mod_pred=clf.predict(X_test) 
print(r2_score(mod_pred, y_test))
# Out:
# 0.8759128574672872

# %% [markdown]
# # Answer A

# %% [markdown]
# # The exercise after this contains questions that are based on the housing dataset.

# %% [markdown]
# # 10. How many houses have a waterfront?
# # a. 21000
# # b. 21450
# # c. 163
# # d. 173

# %%
h_data = pd.read_csv("housing.csv")

# %%
h_data[h_data["waterfront"]>0]["waterfront"].count()
# Out:
# 163

# %% [markdown]
# # Answer C

# %% [markdown]
# # 11. How many houses have 2 floors?
# # a. 2692
# # b. 8241
# # c. 10680
# # d. 161

# %%
h_data[h_data["floors"]==2]["floors"].count()
# Out:
# 8241

# %% [markdown]
# # Answer B

# %% [markdown]
# # 12. How many houses built before 1960 have a waterfront?
# # a. 80
# # b. 7309
# # c. 90
# # d. 92

# %%
h_data[ ((h_data["yr_built"]<1960) & (h_data["waterfront"]>0))].count()["yr_built"]
# Out:
# 80

# %% [markdown]
# # Answer A

# %% [markdown]
# # 13. What is the price of the most expensive house having more than 4
# # bathrooms?
# # a. 7700000
# # b. 187000
# # c. 290000
# # d. 399000

# %%
h_data.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
h_data[h_data["bathrooms"]>=4]["price"].max()
# Out:
# 7700000

# %% [markdown]
# # Answer A

# %% [markdown]
# # 14. The image shown below shows the boxplot of the price column from the housing dataset. What inferences can you make from the plot?
# ![image.png](attachment:ac11fdd3-8d6d-40f0-becd-e4e67d0fdbe5.png)

# %%
sns.boxplot(x='price', data=h_data)
plt.show()

# %% [markdown]
# # Answer C

# %% [markdown]
# # 15. For instance, if the ‘price’ column consists of outliers, how can you make the data clean and remove the redundancies?
# # a. Calculate the IQR range and drop the values outside the range.
# # b. Calculate the p-value and remove the values less than 0.05.
# # c. Calculate the correlation coefficient of the price column and remove the values less than the correlation coefficient.
# # d. Calculate the Z-score of the price column and remove the values less than the z-score.

# %% [markdown]
# # Answer A

# %% [markdown]
# # 16. What are the various parameters that can be used to determine the dependent variables in the housing data to determine the price of the house?
# # a. Correlation coefficients
# # b. Z-score
# # c. IQR Range
# # d. Range of the Features

# %%
# The Pearson correlation coefficient can be easily calculated in Pandas using corr() . 
# A correlation coefficient is a numerical measure of some type of correlation, meaning a statistical relationship 
#  between two variables. The variables may be two columns of a given data set of observations, often called a sample, or two components of a multivariate random variable with a known distribution.
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %% [markdown]
# # Answer A

# %% [markdown]
# # 17. If we get the r2 score as 0.38, what inferences can we make about the model and its efficiency?
# # a. The model is 38% accurate, and shows poor efficiency.
# # b. The model is showing 0.38% discrepancies in the outcomes.
# # c. Low difference between observed and fitted values.
# # d. High difference between observed and fitted values.

# %% [markdown]
# # The coefficient of determination (R²) is a number between 0 and 1 that measures how well a statistical model predicts an outcome. The outcome is represented by the model’s dependent variable. The lowest possible value of R² is 0 and the highest possible value is 1. Put simply, the better a model is at making predictions, the closer its R² will be to 1. If the R² is 0, the linear regression model doesn’t allow you to predict any better than simply estimating that everyone has an average score. If the R² is between 0 and 1, the model allows you to partially predict the outcome. The model’s estimates are not perfect, but they’re better than simply using the average score. If the R² is 1, the model allows you to perfectly predict anyone’s score1.
#
# # Therefore, if we get an R² score of 0.38, it means that the model partially predicts the outcome with a low difference between observed and fitted values1.
#
# # So option c is correct.

# %% [markdown]
# # Answer C

# %% [markdown]
# # 18. If the metrics show that the p-value for the grade column is 0.092, what all inferences can we make about the grade column?
# # a. Significant in presence of other variables.
# # b. Highly significant in presence of other variables
# # c. insignificance in presence of other variables
# # d. None of the above

# %% [markdown]
# # The p-value is a number, calculated from a statistical test, that describes how likely you are to have found a particular set of observations if the null hypothesis were true. P values are used in hypothesis testing to help decide whether to reject the null hypothesis. The smaller the p value, the more likely you are to reject the null hypothesis. If the p-value for the grade column is 0.092, it means that it is not statistically significant1. Therefore option c is correct.

# %% [markdown]
# # Answer C

# %% [markdown]
# # 19. If the Variance Inflation Factor value for a feature is considerably higher than the other features, what can we say about that column/feature?
# # a. High multicollinearity
# # b. Low multicollinearity
# # c. Both A and B
# # d. None of the above

# %% [markdown]
# # Answer A
