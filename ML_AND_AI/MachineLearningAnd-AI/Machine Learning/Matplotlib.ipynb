# %% [markdown]
# # Description of the Dataset:
#     This dataset contains these columns: id, date, price, bedrooms, bathrooms,
#     sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above,
#     sqft_basement, yr_built, yr_renovated, zip code, lat, long, sqft_living15, sqft_lot15.
#     Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("home_data.csv")
# sdata = sns.load_dataset("home_data")
data.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
sns.scatterplot(data = data, x="price", y="bedrooms", linewidth =0, alpha = 0.1,  hue='grade' )
# Out:
# <Axes: xlabel='price', ylabel='bedrooms'>

# %% [markdown]
# # Python Correlation: Creating A Scatter Plot

# %%
sns.scatterplot(data = data, x="price", y="grade", linewidth =0, alpha = 0.2 )
# Out:
# <Axes: xlabel='price', ylabel='grade'>

# %% [markdown]
# # Python Correlation: Creating A Regression Plot

# %%
sns.regplot (data = data, x="price", y="grade")
# Out:
# <Axes: xlabel='price', ylabel='grade'>

# %%
# change color effect
scatter_kws={"color" : "white", "edgecolor" : "grey", "alpha" : 0.4}
line_kws={"color" : "red", "linewidth" : 1}
sns.regplot (data = data, x="price", y="grade", scatter_kws=scatter_kws, line_kws=line_kws)
# Out:
# <Axes: xlabel='price', ylabel='grade'>

# %%
sns.relplot(data=data, x="sqft_living", y="grade", hue="price")

# %% [markdown]
# # Python Correlation: Creating A Correlation Matrix

# %%
data.corr()
# Out:
# C:\Users\27746\AppData\Local\Temp\ipykernel_22796\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# ...

# %% [markdown]
# # Python Correlation: Creating a Heat Map

# %%
# Creating heat map
fig = plt.figure(figsize = (10,5))
sns.heatmap(data.corr())
# Out:
# C:\Users\27746\AppData\Local\Temp\ipykernel_22796\2224088035.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %%
# Creating heat map
fig = plt.figure(figsize = (10,5))
sns.heatmap(data.corr(), linewidths=0.5, annot=True)
# Out:
# C:\Users\27746\AppData\Local\Temp\ipykernel_22796\3946355612.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), linewidths=0.5, annot=True)
# <Axes: >

# %%
# Creating heat map
fig = plt.figure(figsize = (11,10))
sns.heatmap(data.corr(method="spearman"), linewidths=0.5, annot=True)
# Out:
# C:\Users\27746\AppData\Local\Temp\ipykernel_22796\1739828820.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(method="spearman"), linewidths=0.5, annot=True)
# <Axes: >

# %% [markdown]
# # Python Correlation: Creating a Staircase Visual

# %%
import numpy as np
fig = plt.figure(figsize = (11,5))
plt.style.use("default")
df_corr = data.corr()
mask = np.triu(np.ones_like(df_corr,dtype="bool"))
sns.heatmap(data.corr(method="spearman"), mask=mask, linewidth=1, annot=True,cmap="coolwarm")
# Out:
# C:\Users\27746\AppData\Local\Temp\ipykernel_22796\2888830374.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = data.corr()
# C:\Users\27746\AppData\Local\Temp\ipykernel_22796\2888830374.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(method="spearman"), mask=mask, linewidth=1, annot=True,cmap="coolwarm")
# <Axes: >

# %%
# sns.box(x=data["price"],y=data["sqft_above"])
fig = plt.figure(figsize = (11,5))

data.boxplot(by ='price', column =['sqft_above'], grid = False)
# Out:
# <Axes: title={'center': 'sqft_above'}, xlabel='price'>

# %%
filter_year = data["yr_built"]>=2013
data_aftr_2014 = data[filter_year]
sns.set_style("whitegrid")
sns.boxplot(x = 'price', y = 'sqft_above', data = data_aftr_2014, hue='yr_built' )

# %%
# sns.box(x="price", y="sqft_above")
filter_year = data["yr_built"]>=2013
data_aftr_2014 = data[filter_year]
sns.set_style("whitegrid")
sns.boxplot(x = 'price', y = 'sqft_above', data = data_aftr_2014, hue='yr_built' )
# Out:
# <Axes: xlabel='price', ylabel='sqft_above'>

# %% [markdown]
# # 1. Which of the following libraries should be imported for creating charts in python?
#     a. Pandas
#     b. Random
#     c. Math
#     d. Matplotlib

# %% [markdown]
# # Answer D

# %% [markdown]
# # 2. How to visualize the correlation pattern in the dataset?
#     a. Histogram
#     b. Bar plot
#     c. Scatterplot
#     d. Heatmap

# %% [markdown]
# # Answer D

# %% [markdown]
# # 3. Which function can we use for plotting the boxplot?
#     a. sns.box()
#     b. plt.bplot()
#     c. sns.boxplot()
#     d. pl.boxplt()

# %% [markdown]
# # Answer C

# %% [markdown]
# # 4. What insights can we extract from the boxplot?
#     a. 2nd quartile
#     b. 1st quadrille
#     c. 3rd quartile
#     d. All of the above

# %% [markdown]
# # Answer D

# %% [markdown]
# #

# %% [markdown]
# # 5. Which visualization is not part of matplotlib?
#     a. Table plot
#     b. Area plot
#     c. Violin plot
#     d. All of the above

# %% [markdown]
# # Answer A

# %% [markdown]
# # 6. From which visualization we can find the median/mean value of the data?
#     a. Bar plot
#     b. Boxplot
#     c. Violin plot
#     d. All of the above

# %% [markdown]
# # Answer B

# %% [markdown]
# # 7. Which of the following is correct?
#     a. plt.scatter(data[‘gender’],data[‘age’])
#     b. plt.boxpt(data[‘gender’],data[‘age’])
#     c. plt.scatter(data[‘salary’],data[‘age’])
#     d. None of the above

# %% [markdown]
# # Answer D --> A and B are correct code but csv data doesn't contains gender age and salay

# %% [markdown]
# # 8. What error you will get after executing the below code: data.box('bedrooms','grade')
#     a. Attribute error
#     b. Syntax error
#     c. Runtime error
#     d. None of the above

# %% [markdown]
# # Answer A

# %% [markdown]
# # 9. Which of the following code you can use for plotting the pie chart:
#     a. plt.pie(x)
#     b. sns.pie(x)
#     c. Both of the above
#     d. None of the above

# %% [markdown]
# # Answer A

# %% [markdown]
# # 10. What is the correct way of plotting violin plot?
#     a. sns.violinplot(data=data, y = 'price',x 'waterfront')
#     b. sns.violin(data=data, y = 'price',x = 'waterfront')
#     c. plt.violinplot(data=data, y = 'price',x='waterfront')
#     d. All of the above

# %% [markdown]
# # Answer A

# %% [markdown]
# # 11. Select the incorrect syntax:
#     a. plt.figsize()
#     b. plt.figtext()
#     c. plt.figpic()
#     d. Both A and C

# %% [markdown]
# # Answer D

# %% [markdown]
# # 12. What inference you can extract from the below graph:
# ![image.png](attachment:ae632156-9336-42cf-9fcf-c42b29f345c4.png)
# # a. The cheapest house is having 3 floors.
# # b. The costliest house is having 2.5 floors.
# # c. The maximum number of houses are having 1 floor
# # only
# # d. All of the above

# %% [markdown]
# # Answer B

# %% [markdown]
# # 13. Which of the following statements are correct with respect to the below image:
#
# ![image.png](attachment:d7683e28-ce64-4490-a380-aa83ac0662f6.png)
#
# # a. The maximum number of houses have grades of either 7 or 8.
# # b. Around 2000 houses are having grades between 6 and 7.
# # c. Both of the above.
# # d. None of the above.

# %% [markdown]
# ![image.png](attachment:ec09a70c-ecf2-4c2b-a93b-583d5b8aed23.png)

# %% [markdown]
# # Answer A and C

# %% [markdown]
# ![image.png](attachment:12d73db3-f548-4985-86f0-dc9c9c68b14c.png)

# %% [markdown]
# # Answer A

# %% [markdown]
# ![image.png](attachment:f002531d-4645-4eb7-8ced-9b3697a47894.png)

# %% [markdown]
# # Answer C
